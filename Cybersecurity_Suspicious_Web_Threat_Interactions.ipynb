# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayasri4002/laptopprices/blob/main/Cybersecurity_Suspicious_Web_Threat_Interactions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data import

# %%
import pandas as pd

df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

df.head()
# Out:
#    bytes_in  bytes_out         creation_time              end_time  \
# 0      5602      12990  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 1     30912      18186  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 2     28506      13468  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 3     30546      14278  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 4      6526      13892  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
#
#             src_ip src_ip_country_code protocol  response.code  dst_port  \
# 0   147.161.161.82                  AE    HTTPS            200       443
# 1     165.225.33.6                  US    HTTPS            200       443
# 2  165.225.212.255                  CA    HTTPS            200       443
# 3   136.226.64.114                  US    HTTPS            200       443
# 4   165.225.240.79                  NL    HTTPS            200       443
#
#          dst_ip              rule_names                      observation_name  \
# ...

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-833a4398-172d-4000-84ea-f3ac9c936325" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-833a4398-172d-4000-84ea-f3ac9c936325">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')
df.head()
# Out:
#    bytes_in  bytes_out         creation_time              end_time  \
# 0      5602      12990  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 1     30912      18186  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 2     28506      13468  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 3     30546      14278  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 4      6526      13892  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
#
#             src_ip src_ip_country_code protocol  response.code  dst_port  \
# 0   147.161.161.82                  AE    HTTPS            200       443
# 1     165.225.33.6                  US    HTTPS            200       443
# 2  165.225.212.255                  CA    HTTPS            200       443
# 3   136.226.64.114                  US    HTTPS            200       443
# 4   165.225.240.79                  NL    HTTPS            200       443
#
#          dst_ip              rule_names                      observation_name  \
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

df.head()
# Out:
#    bytes_in  bytes_out         creation_time              end_time  \
# 0      5602      12990  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 1     30912      18186  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 2     28506      13468  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 3     30546      14278  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 4      6526      13892  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
#
#             src_ip src_ip_country_code protocol  response.code  dst_port  \
# 0   147.161.161.82                  AE    HTTPS            200       443
# 1     165.225.33.6                  US    HTTPS            200       443
# 2  165.225.212.255                  CA    HTTPS            200       443
# 3   136.226.64.114                  US    HTTPS            200       443
# 4   165.225.240.79                  NL    HTTPS            200       443
#
#          dst_ip              rule_names                      observation_name  \
# ...

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# 1. Remove duplicate rows
df = df.drop_duplicates()

# 2. Convert time columns to datetime
df['creation_time'] = pd.to_datetime(df['creation_time'])
df['end_time'] = pd.to_datetime(df['end_time'])
df['time'] = pd.to_datetime(df['time'])

# 3. Standardize country codes (uppercase)
df['src_ip_country_code'] = df['src_ip_country_code'].str.upper()

# 4. Check missing values
print("Missing values:\n", df.isnull().sum())

# 5. New feature: session duration in seconds
df['duration_seconds'] = (df['end_time'] - df['creation_time']).dt.total_seconds()

# Show first rows
df.head()
# Out:
# Missing values:
#  bytes_in               0
# bytes_out              0
# creation_time          0
# end_time               0
# src_ip                 0
# src_ip_country_code    0
# protocol               0
# response.code          0
# dst_port               0
# dst_ip                 0
# rule_names             0
# observation_name       0
# source.meta            0
# source.name            0
# time                   0
# detection_types        0
# dtype: int64
#    bytes_in  bytes_out             creation_time                  end_time  \
# 0      5602      12990 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00
# 1     30912      18186 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00
# 2     28506      13468 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00
# 3     30546      14278 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00
# 4      6526      13892 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00
#
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# -------------------------------
# 1. Distribution of bytes_in
# -------------------------------
plt.figure(figsize=(8,5))
plt.hist(df['bytes_in'], bins=20, color='orange')
plt.title("Distribution of bytes_in")
plt.xlabel("bytes_in")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# -------------------------------
# 2. Distribution of bytes_out
# -------------------------------
plt.figure(figsize=(8,5))
plt.hist(df['bytes_out'], bins=20, color='orange')
plt.title("Distribution of bytes_out")
plt.xlabel("bytes_out")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# -------------------------------
# 3. Protocol Count
# -------------------------------
plt.figure(figsize=(8,5))
protocol_counts = df['protocol'].value_counts()
plt.bar(protocol_counts.index, protocol_counts.values, color='orange')
plt.title("Protocol Count")
plt.xlabel("Protocol")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# -------------------------------
# 4. Source Country Code Count
# -------------------------------
plt.figure(figsize=(8,5))
country_counts = df['src_ip_country_code'].value_counts()
plt.bar(country_counts.index, country_counts.values, color='orange')
plt.title("Source Country Code Count")
plt.xlabel("Country Code")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %% [markdown]
# Feature Engineering

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert time columns to datetime
df['creation_time'] = pd.to_datetime(df['creation_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# Duration of session in seconds
df['duration_seconds'] = (df['end_time'] - df['creation_time']).dt.total_seconds()

df[['creation_time', 'end_time', 'duration_seconds']].head()
# Out:
#               creation_time                  end_time  duration_seconds
# 0 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00             600.0
# 1 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00             600.0
# 2 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00             600.0
# 3 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00             600.0
# 4 2024-04-25 23:00:00+00:00 2024-04-25 23:10:00+00:00             600.0

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert time columns to datetime
df['creation_time'] = pd.to_datetime(df['creation_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# Duration of session in seconds
df['duration_seconds'] = (df['end_time'] - df['creation_time']).dt.total_seconds()

# --------------------------------------------
# Average Packet Size Formula
# (bytes_in + bytes_out) / duration_seconds
# --------------------------------------------

df['avg_packet_size'] = (df['bytes_in'] + df['bytes_out']) / df['duration_seconds']

# Show results
df[['bytes_in', 'bytes_out', 'duration_seconds', 'avg_packet_size']].head()
# Out:
#    bytes_in  bytes_out  duration_seconds  avg_packet_size
# 0      5602      12990             600.0        30.986667
# 1     30912      18186             600.0        81.830000
# 2     28506      13468             600.0        69.956667
# 3     30546      14278             600.0        74.706667
# 4      6526      13892             600.0        34.030000

# %% [markdown]
# Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Country-Based Interaction Analysis
plt.figure(figsize=(12, 6))
sns.countplot(y='src_ip_country_code', data=df,
              order=df['src_ip_country_code'].value_counts().index,
              palette='viridis')

plt.title('Interaction Count by Source IP Country Code')
plt.xlabel('Count')
plt.ylabel('Country Code')
plt.show()
# Out:
# /tmp/ipython-input-2513551837.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='src_ip_country_code', data=df,

# %%
# Suspicious Activities Based on Destination Port
plt.figure(figsize=(12, 6))
sns.countplot(x='dst_port',
              data=df[df['detection_types'] == 'waf_rule'],
              palette='coolwarm')

plt.title('Suspicious Activities Based on Destination Port')
plt.xlabel('Destination Port')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-1792650674.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='dst_port',

# %% [markdown]
# Modeling: Anomaly Detection

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert time columns to datetime
df['creation_time'] = pd.to_datetime(df['creation_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# Feature Engineering
df['duration_seconds'] = (df['end_time'] - df['creation_time']).dt.total_seconds()
df['avg_packet_size'] = (df['bytes_in'] + df['bytes_out']) / df['duration_seconds']

# ------------------------------
# Select features for anomaly detection
# ------------------------------
features = df[['bytes_in', 'bytes_out', 'duration_seconds', 'avg_packet_size']]

# ------------------------------
# Initialize Isolation Forest model
# ------------------------------
model = IsolationForest(contamination=0.05, random_state=42)

# Fit the model and predict
df['anomaly'] = model.fit_predict(features)

# Convert -1 → Suspicious, 1 → Normal
df['anomaly'] = df['anomaly'].replace({-1: 'Suspicious', 1: 'Normal'})

# Show results
df[['bytes_in', 'bytes_out', 'duration_seconds', 'avg_packet_size', 'anomaly']].head()
# Out:
#    bytes_in  bytes_out  duration_seconds  avg_packet_size anomaly
# 0      5602      12990             600.0        30.986667  Normal
# 1     30912      18186             600.0        81.830000  Normal
# 2     28506      13468             600.0        69.956667  Normal
# 3     30546      14278             600.0        74.706667  Normal
# 4      6526      13892             600.0        34.030000  Normal

# %% [markdown]
# Evaluation

# %%
# 1. Count how many Normal vs Suspicious
anomaly_counts = df['anomaly'].value_counts()
print("Anomaly Count:\n", anomaly_counts)

# 2. Percentage of anomalies
print("\nAnomaly Percentage:")
print((anomaly_counts / len(df)) * 100)

# 3. Show suspicious activities (anomalies)
suspicious_samples = df[df['anomaly'] == 'Suspicious']
print("\nSuspicious Samples:")
print(suspicious_samples.head())
# Out:
# Anomaly Count:
#  anomaly
# Normal        267
# Suspicious     15
# Name: count, dtype: int64
#
# Anomaly Percentage:
# anomaly
# Normal        94.680851
# Suspicious     5.319149
# Name: count, dtype: float64
#
# Suspicious Samples:
#      bytes_in  bytes_out             creation_time                  end_time  \
# 36    4190330     283456 2024-04-25 23:30:00+00:00 2024-04-25 23:40:00+00:00
# 87    1215594      64362 2024-04-26 00:30:00+00:00 2024-04-26 00:40:00+00:00
# 116   4827283     306181 2024-04-26 01:00:00+00:00 2024-04-26 01:10:00+00:00
# 132   1889834      34306 2024-04-26 01:20:00+00:00 2024-04-26 01:30:00+00:00
# 153   4869181     301752 2024-04-26 01:40:00+00:00 2024-04-26 01:50:00+00:00
#
#              src_ip src_ip_country_code protocol  response.code  dst_port  \
# 36    155.91.45.242                  US    HTTPS            200       443
# 87   165.225.240.79                  NL    HTTPS            200       443
# ...

# %% [markdown]
# Visualization of Anomalies

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.scatterplot(
    x='bytes_in',
    y='bytes_out',
    hue='anomaly',
    data=df,
    palette={'Normal': 'green', 'Suspicious': 'red'}
)

plt.title('Anomalies in Bytes In vs Bytes Out')
plt.xlabel('Bytes In')
plt.ylabel('Bytes Out')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert time columns if needed
df['creation_time'] = pd.to_datetime(df['creation_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# Feature Engineering
df['duration_seconds'] = (df['end_time'] - df['creation_time']).dt.total_seconds()
df['avg_packet_size'] = (df['bytes_in'] + df['bytes_out']) / df['duration_seconds']

# Select only numeric columns for correlation
numeric_df = df[['bytes_in', 'bytes_out', 'duration_seconds', 'avg_packet_size']]

# Correlation Matrix
corr_matrix = numeric_df.corr()

# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Create crosstab (Country vs Detection Types)
detection_by_country = pd.crosstab(df['src_ip_country_code'], df['detection_types'])

# Plot stacked bar chart
detection_by_country.plot(kind='bar', stacked=True, figsize=(12,6))

plt.title('Detection Types by Country Code')
plt.xlabel('Country Code')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.legend(title='Detection Type')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert creation_time to datetime
df['creation_time'] = pd.to_datetime(df['creation_time'])

# Set creation_time as index
df.set_index('creation_time', inplace=True)

# Plot time-series
plt.figure(figsize=(12, 6))

plt.plot(df.index, df['bytes_in'], marker='o', label='Bytes In')
plt.plot(df.index, df['bytes_out'], marker='o', label='Bytes Out')

plt.title('Web Traffic Analysis Over Time')
plt.xlabel('Time')
plt.ylabel('Bytes')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Create a graph
G = nx.Graph()

# Add edges (Source IP → Destination IP)
for index, row in df.iterrows():
    G.add_edge(row['src_ip'], row['dst_ip'])

# Draw the network graph
plt.figure(figsize=(14, 10))
nx.draw_networkx(
    G,
    with_labels=True,
    node_size=20,
    font_size=8,
    node_color='skyblue',
    font_color='darkblue'
)

plt.title('Network Interaction between Source and Destination IPs')
plt.axis('off')  # Hide axis
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert time columns to datetime
df['creation_time'] = pd.to_datetime(df['creation_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# Feature Engineering
df['duration_seconds'] = (df['end_time'] - df['creation_time']).dt.total_seconds()

# Label: 1 = suspicious, 0 = normal
df['is_suspicious'] = (df['detection_types'] == 'waf_rule').astype(int)

# Features (simple numeric features)
X = df[['bytes_in', 'bytes_out', 'duration_seconds']]
y = df['is_suspicious']

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Predictions
y_pred = rf.predict(X_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Model Accuracy:", accuracy)
print("\nClassification Report:\n", report)
# Out:
# Model Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        85
#
#     accuracy                           1.00        85
#    macro avg       1.00      1.00      1.00        85
# weighted avg       1.00      1.00      1.00        85

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Convert detection type into binary label
df['is_suspicious'] = (df['detection_types'] == 'waf_rule').astype(int)

# -------- FEATURES --------
X = df[['bytes_in', 'bytes_out']].values
y = df['is_suspicious'].values

# -------- TRAIN - TEST SPLIT --------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# -------- SCALING --------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# -------- NEURAL NETWORK MODEL --------
model = Sequential([
    Dense(8, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# -------- COMPILE --------
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# -------- TRAIN MODEL --------
history = model.fit(X_train_scaled, y_train, epochs=10, batch_size=8, verbose=1)

# -------- EVALUATE MODEL --------
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3626 - loss: 0.7140
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.6387
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.5793
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.5061
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.4208
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3317
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2520
# Epoch 8/10
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Create label (1 = suspicious, 0 = normal)
df['is_suspicious'] = (df['detection_types'] == 'waf_rule').astype(int)

# ---------------------------
# FEATURES AND LABELS
# ---------------------------
X = df[['bytes_in', 'bytes_out']].values
y = df['is_suspicious'].values

# ---------------------------
# TRAIN-TEST SPLIT
# ---------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ---------------------------
# FEATURE SCALING
# ---------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ---------------------------
# 1. BUILD THE MODEL
# ---------------------------
model = Sequential([
    Dense(8, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# ---------------------------
# 2. COMPILE THE MODEL
# ---------------------------
model.compile(
    optimizer=Adam(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ---------------------------
# 3. TRAIN THE MODEL
# ---------------------------
history = model.fit(
    X_train_scaled, y_train,
    epochs=10,
    batch_size=8,
    verbose=1
)

# ---------------------------
# 4. EVALUATE THE MODEL
# ---------------------------
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 0.6440
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.5745
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.4893
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.3938
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.2862
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.1836
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1106
# Epoch 8/10
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/CloudWatch_Traffic_Web_Attack (1).csv')

# Label: suspicious = 1
df['is_suspicious'] = (df['detection_types'] == 'waf_rule').astype(int)

# Features
X = df[['bytes_in', 'bytes_out']].values
y = df['is_suspicious'].values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Scaling
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# Build model
model = Sequential([
    Dense(8, activation='relu', input_shape=(X_train_s.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(X_train_s, y_train, epochs=10, batch_size=8, verbose=1)

# Evaluate
loss, accuracy = model.evaluate(X_test_s, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
print(f"Test Loss: {loss:.4f}")

# ------------------------------
# Plot Accuracy and Loss
# ------------------------------

plt.figure(figsize=(12,5))

# Accuracy Plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# Loss Plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 0.6272
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.5316
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.4438
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.3533
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.2636
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.1915
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1337
# Epoch 8/10
# ...
